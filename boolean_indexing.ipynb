# %%
import numpy as np

arr = np.arange(1, 6)
print(arr)

# %%
bool_index = arr > 2
print(bool_index)

# %%
arr[bool_index]

# %%
arr = np.array([[5, 15, 25],
                [30, 40, 50]])
print(arr)

# %%
arr[arr > 25]
